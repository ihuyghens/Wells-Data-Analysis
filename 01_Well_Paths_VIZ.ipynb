# %% [markdown]
# # Visualizing Well Paths With The Welly Python Library
# Creating 3D Line Plots Using Matplotlib to Visualize Well Trajectories
#
# ![alt text](well_paths.png "Well Paths")

# %%
# importing libraries & load data

# Wells data library
from welly import Location
from welly import Well

# Numeric and matrix library
import pandas as pd

#import matplotlib.pyplot as plt
#import lasio

# %%
data = Well.from_las('Data/newslaslogs/11-28.las')

# %%
data
# Out:
# Well(uwi: '1539400', name: 'SAN EMIDIO A 11-28', 27 curves: ['AM16', 'AO10', 'AO19', 'AZIM', 'DEVI', 'EAST', 'LTHE', 'MCRV', 'MM', 'NORT', 'OFFS', 'PHES', 'PHTS', 'PHZC', 'RD', 'RM', 'ROMX', 'RS', 'SBL', 'SCLN', 'SP', 'SPN', 'TVD', 'VCDS', 'VCLY', 'VCWS', 'VSHS'])

# %%
data.data
# Out:
# {'AM16': Curve(mnemonic=AM16, units=OHMM, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'AO10': Curve(mnemonic=AO10, units=OHMM, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'AO19': Curve(mnemonic=AO19, units=OHMM, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'AZIM': Curve(mnemonic=AZIM, units=DEG, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'DEVI': Curve(mnemonic=DEVI, units=DEG, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'EAST': Curve(mnemonic=EAST, units=FT, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'LTHE': Curve(mnemonic=LTHE, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'MCRV': Curve(mnemonic=MCRV, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'MM': Curve(mnemonic=MM, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'NORT': Curve(mnemonic=NORT, units=FT, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'OFFS': Curve(mnemonic=OFFS, units=FT, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'PHES': Curve(mnemonic=PHES, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'PHTS': Curve(mnemonic=PHTS, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'PHZC': Curve(mnemonic=PHZC, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'RD': Curve(mnemonic=RD, units=OHMM, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'RM': Curve(mnemonic=RM, units=OHMM, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'ROMX': Curve(mnemonic=ROMX, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'RS': Curve(mnemonic=RS, units=OHMM, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'SBL': Curve(mnemonic=SBL, units=MV, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'SCLN': Curve(mnemonic=SCLN, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[12510]),
#  'SP': Curve(mnemonic=SP, units=MV, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'SPN': Curve(mnemonic=SPN, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'TVD': Curve(mnemonic=TVD, units=FT, start=656.0000, stop=7084.0000, step=0.5000, count=[12857]),
#  'VCDS': Curve(mnemonic=VCDS, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'VCLY': Curve(mnemonic=VCLY, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'VCWS': Curve(mnemonic=VCWS, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081]),
#  'VSHS': Curve(mnemonic=VSHS, units=, start=656.0000, stop=7084.0000, step=0.5000, count=[4081])}

# %%
data.plot(extents='curves')

# %%
#survey = pd.read_csv('Data/L05-15-Survey.csv)
